# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import os

# %%
os.chdir('/home/tapas/Downloads/mohit/')
os.listdir(".")
# Out:
# ['Smartphone purchase behaviour.csv']

# %%
df = pd.read_csv('Smartphone purchase behaviour.csv')

# %%
df.shape
# Out:
# (192, 20)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which brand of smartphone you use?', 'Availability',
#        'Brand', 'After Sales service', 'Advertisement', 'Referral - Friend',
#        'Referral - Shop', 'Price & discounts', 'RAM and Processor', 'Camera',
#        'Design', 'Operating System', 'Storage Capacity', 'Battery',
#        'Screen Size & Resolution', 'How Much did you pay for your smartphone?',
#        'Your Age?', 'Gender', 'Your education?'],
#       dtype='object')

# %%
df.head(5)
# Out:
#                          Timestamp Which brand of smartphone you use?  \
# 0   2017/07/16 9:43:30 PM GMT+5:30                               Qiku
# 1   2017/07/16 9:53:06 PM GMT+5:30                              Let v
# 2  2017/07/16 10:13:01 PM GMT+5:30                              Let v
# 3  2017/07/16 10:13:53 PM GMT+5:30                               OPPO
# 4  2017/07/16 10:13:56 PM GMT+5:30                              Apple
#
#    Availability  Brand  After Sales service  Advertisement  Referral - Friend  \
# 0             2      2                    3              1                  2
# 1             4      3                    3              2                  4
# 2             4      3                    3              2                  5
# 3             5      4                    4              5                  3
# 4             4      5                    5              4                  4
#
#    Referral - Shop  Price & discounts  RAM and Processor  Camera  Design  \
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                                    0
# Which brand of smartphone you use?           0
# Availability                                 0
# Brand                                        0
# After Sales service                          0
# Advertisement                                0
# Referral - Friend                            0
# Referral - Shop                              0
# Price & discounts                            0
# RAM and Processor                            0
# Camera                                       0
# Design                                       0
# Operating System                             0
# Storage Capacity                             0
# Battery                                      0
# Screen Size & Resolution                     0
# How Much did you pay for your smartphone?    0
# Your Age?                                    0
# Gender                                       0
# Your education?                              0
# dtype: int64

# %%
df.describe()
# Out:
#        Availability       Brand  After Sales service  Advertisement  \
# count    192.000000  192.000000           192.000000     192.000000
# mean       3.598958    4.020833             3.822917       3.010417
# std        1.253518    1.130067             1.038472       1.244841
# min        1.000000    1.000000             1.000000       1.000000
# 25%        3.000000    3.750000             3.000000       2.000000
# 50%        4.000000    4.000000             4.000000       3.000000
# 75%        5.000000    5.000000             5.000000       4.000000
# max        5.000000    5.000000             5.000000       5.000000
#
#        Referral - Friend  Referral - Shop  Price & discounts  \
# count         192.000000       192.000000         192.000000
# mean            3.515625         2.677083           3.755208
# std             1.197627         1.244841           1.178993
# min             1.000000         1.000000           1.000000
# ...

# %%
#histogram
sns.distplot(df['Availability']);

# %%
#histogram
sns.distplot(df['Brand']);

# %%
#histogram
sns.distplot(df['After Sales service']);

# %%
#histogram
sns.distplot(df['Advertisement']);

# %%
#histogram
sns.distplot(df['Referral - Friend']);

# %%
#histogram
sns.distplot(df['Referral - Shop']);

# %%
#histogram
sns.distplot(df['Price & discounts']);

# %%
#histogram
sns.distplot(df['RAM and Processor']);

# %%
#histogram
sns.distplot(df['Camera']);

# %%
#histogram
sns.distplot(df['Operating System']);

# %%
#histogram
sns.distplot(df['Storage Capacity']);

# %%
#histogram
sns.distplot(df['Battery']);

# %%
#histogram
sns.distplot(df['Screen Size & Resolution']);

# %%
df.columns
# Out:
# Index(['Timestamp', 'Which brand of smartphone you use?', 'Availability',
#        'Brand', 'After Sales service', 'Advertisement', 'Referral - Friend',
#        'Referral - Shop', 'Price & discounts', 'RAM and Processor', 'Camera',
#        'Design', 'Operating System', 'Storage Capacity', 'Battery',
#        'Screen Size & Resolution', 'How Much did you pay for your smartphone?',
#        'Your Age?', 'Gender', 'Your education?'],
#       dtype='object')

# %%
del df['Timestamp']

# %%
#box plot overallqual/saleprice
var = 'Gender'
data = pd.concat([df['Camera'], df[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="Camera", data=data)
fig.axis(ymin=0, ymax=10);

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
sns.boxplot(x="Gender", y="Availability", data=df);

# %%
num_var = ['Availability', 'Brand','After Sales service', 'Advertisement', 'Referral - Friend',
       'Referral - Shop', 'Price & discounts', 'RAM and Processor', 'Camera',
       'Design', 'Operating System', 'Storage Capacity', 'Battery',
       'Screen Size & Resolution']

# %%
df.groupby(['Which brand of smartphone you use?']).mean()
# Out:
#                                     Availability     Brand  \
# Which brand of smartphone you use?
# Apple                                   4.000000  4.565217
# GIONEE                                  4.000000  2.000000
# Gionee                                  4.000000  4.000000
# Gionne                                  5.000000  1.000000
# Google Pixel                            2.000000  5.000000
# Google pixel XL                         5.000000  5.000000
# HTC                                     4.000000  4.000000
# Honor pro                               3.000000  3.000000
# LG                                      4.000000  5.000000
# Lava                                    1.000000  2.000000
# Lavairis x-8                            5.000000  5.000000
# Le1s                                    1.000000  3.000000
# Lenevo                                  5.000000  4.000000
# Lenovo                                  3.500000  3.250000
# ...

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df.groupby(['Which brand of smartphone you use?']).hist(bins=bin_values, figsize=[14,6])
# Out:
# Which brand of smartphone you use?
# Apple                   [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# GIONEE                  [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Gionee                  [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Gionne                  [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Google Pixel            [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Google pixel XL         [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# HTC                     [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Honor pro               [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# LG                      [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Lava                    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Lavairis x-8            [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Le1s                    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# ...

# %%
df.groupby(['Your education?']).mean()
# Out:
#                  Availability     Brand  After Sales service  Advertisement  \
# Your education?
# Graduate             3.740000  4.220000             3.800000       2.920000
# Intermediate         2.250000  1.875000             2.250000       1.875000
# Post Graduate        3.642857  4.102041             4.020408       3.091837
# Undergraduate        3.583333  4.000000             3.666667       3.166667
#
#                  Referral - Friend  Referral - Shop  Price & discounts  \
# Your education?
# Graduate                  3.760000         2.720000           3.740000
# Intermediate              2.000000         1.750000           3.000000
# Post Graduate             3.571429         2.673469           3.887755
# Undergraduate             3.361111         2.833333           3.583333
#
#                  RAM and Processor    Camera    Design  Operating System  \
# Your education?
# Graduate                  4.340000  4.320000  4.460000          4.440000
# ...

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df.groupby(['Your education?']).hist(bins=bin_values, figsize=[14,6])
# Out:
# Your education?
# Graduate         [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Intermediate     [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Post Graduate    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Undergraduate    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# dtype: object

# %%
df.groupby(['Gender']).mean()
# Out:
#         Availability     Brand  After Sales service  Advertisement  \
# Gender
# Female      3.542373  4.152542             3.881356       3.050847
# Male        3.624060  3.962406             3.796992       2.992481
#
#         Referral - Friend  Referral - Shop  Price & discounts  \
# Gender
# Female           3.677966         2.694915           3.847458
# Male             3.443609         2.669173           3.714286
#
#         RAM and Processor    Camera    Design  Operating System  \
# Gender
# Female           4.152542  4.237288  4.135593          4.254237
# Male             4.157895  4.067669  4.135338          4.300752
#
#         Storage Capacity   Battery  Screen Size & Resolution
# Gender
# Female          4.169492  4.186441                  4.338983
# Male            4.157895  4.180451                  4.210526

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df.groupby(['Gender']).hist(bins=bin_values, figsize=[14,6])
# Out:
# Gender
# Female    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Male      [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# dtype: object

# %%
df.groupby(['Your Age?']).mean()
# Out:
#            Availability     Brand  After Sales service  Advertisement  \
# Your Age?
# 20-25          3.578512  4.024793             3.785124       2.983471
# 26-30          3.906977  4.465116             4.255814       3.162791
# 31-35          3.875000  4.000000             4.000000       3.250000
# 35+            3.000000  4.000000             4.000000       3.000000
# Below 20       2.944444  2.944444             2.944444       2.722222
#
#            Referral - Friend  Referral - Shop  Price & discounts  \
# Your Age?
# 20-25               3.561983         2.776860           3.785124
# 26-30               3.790698         2.581395           3.813953
# 31-35               3.500000         2.375000           4.250000
# 35+                 3.000000         3.000000           4.000000
# Below 20            2.611111         2.333333           3.166667
#
#            RAM and Processor    Camera    Design  Operating System  \
# Your Age?
# ...

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df.groupby(['Your Age?']).hist(bins=bin_values, figsize=[14,6])
# Out:
# Your Age?
# 20-25       [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# 26-30       [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# 31-35       [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# 35+         [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Below 20    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# dtype: object

# %%
df.groupby(['How Much did you pay for your smartphone?']).mean()
# Out:
#                                            Availability     Brand  \
# How Much did you pay for your smartphone?
# 10000-14999                                    3.480000  3.853333
# 15000-19999                                    3.647059  4.058824
# 20000-24999                                    3.933333  4.266667
# 25000-29999                                    3.615385  3.923077
# 30000+                                         4.055556  4.777778
# Below 10000                                    2.842105  3.052632
#
#                                            After Sales service  Advertisement  \
# How Much did you pay for your smartphone?
# 10000-14999                                           3.720000       2.986667
# 15000-19999                                           3.705882       3.088235
# 20000-24999                                           4.266667       2.866667
# 25000-29999                                           3.692308       3.692308
# ...

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df.groupby(['How Much did you pay for your smartphone?']).hist(bins=bin_values, figsize=[14,6])
# Out:
# How Much did you pay for your smartphone?
# 10000-14999    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# 15000-19999    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# 20000-24999    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# 25000-29999    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# 30000+         [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# Below 10000    [[Axes(0.125,0.725918;0.158163x0.154082), Axes...
# dtype: object
