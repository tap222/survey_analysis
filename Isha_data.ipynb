# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import os

# %%
os.chdir('/home/tapas/Downloads/isha/')
os.listdir(".")
# Out:
# ['CCDM.csv']

# %%
df = pd.read_csv('CCDM.csv')

# %%
df.shape
# Out:
# (102, 27)

# %%
df.head(5)
# Out:
#   Organisation             Department  Gender       Age  \
# 0         UNDP              Programme  Female  Above 50
# 1         UNDP                    RCO  Female     30-40
# 2         UNDP             Programme   Female  Above 50
# 3         UNDP  Democratic Governance    Male     40-50
# 4         UNDP            Governance   Female     40-50
#
#    Appreciating_Cultural_Differences    Cross-Cultural_Management   \
# 0                                    5                           5
# 1                                    5                           5
# 2                                    4                           4
# 3                                    5                           4
# 4                                    5                           5
#
#     Imparts_Training   sensitizes_Cultural_Differences  \
# 0                   4                                3
# 1                   5                                2
# ...

# %%
df.isnull().sum()
# Out:
# Organisation                                  0
# Department                                    0
# Gender                                        0
# Age                                           0
# Appreciating_Cultural_Differences             0
# Cross-Cultural_Management                     0
#  Imparts_Training                             0
# sensitizes_Cultural_Differences               0
#  Condemns_Discrimination_Cultural             0
#  Different_Cultural_Do_ Not_ Face_Problem     0
#  Conducts_Sensitivity_Training                0
#  Organisation_Celebrates_Festivals            0
# Canteen_Serves_Cuisines                       0
# Cultural_Background_Colleagues                0
# Religious_Customs                             0
# Working _Homogeneous_Teams                    0
# Gender_Inclusivity                            0
# Contextual_Differences                        0
# Treats_men&women_equally                      0
# Recruitment_Gender_Parity                     0
# ...

# %%
df.describe()
# Out:
#        Appreciating_Cultural_Differences    Cross-Cultural_Management   \
# count                           102.000000                  102.000000
# mean                              3.892157                    4.549020
# std                               1.116101                    0.573809
# min                               1.000000                    2.000000
# 25%                               4.000000                    4.000000
# 50%                               4.000000                    5.000000
# 75%                               5.000000                    5.000000
# max                               5.000000                    5.000000
#
#         Imparts_Training   sensitizes_Cultural_Differences  \
# count          102.000000                       102.000000
# mean             3.215686                         3.176471
# std              0.885834                         0.813400
# min              1.000000                         1.000000
# ...

# %%
df.columns
# Out:
# Index(['Organisation', 'Department', 'Gender', 'Age',
#        'Appreciating_Cultural_Differences  ', 'Cross-Cultural_Management ',
#        ' Imparts_Training ', 'sensitizes_Cultural_Differences',
#        ' Condemns_Discrimination_Cultural',
#        ' Different_Cultural_Do_ Not_ Face_Problem ',
#        ' Conducts_Sensitivity_Training', ' Organisation_Celebrates_Festivals ',
#        'Canteen_Serves_Cuisines', 'Cultural_Background_Colleagues ',
#        'Religious_Customs', 'Working _Homogeneous_Teams ',
#        'Gender_Inclusivity ', 'Contextual_Differences',
#        'Treats_men&women_equally', 'Recruitment_Gender_Parity',
#        'Supports_Women_Aspire ', 'Women_Effective_Men_Leadership',
#        'Facilities_Women_Employees', 'Policies_Women_Employees ',
#        'Women_Safety ', ' Prevent_Sexual_Harassment',
#        ' Zero_Tolerance_Sexual_Harassment'],
#       dtype='object')

# %%
init =['Organisation', 'Department', 'Gender', 'Age']
init_p=['Gender_Inclusivity ', 'Contextual_Differences',
       'Treats_men&women_equally', 'Recruitment_Gender_Parity',
       'Supports_Women_Aspire ', 'Women_Effective_Men_Leadership',
       'Facilities_Women_Employees', 'Policies_Women_Employees ',
       'Women_Safety ', ' Prevent_Sexual_Harassment',
       ' Zero_Tolerance_Sexual_Harassment']
init_s=['Appreciating_Cultural_Differences  ', 'Cross-Cultural_Management ',
       ' Imparts_Training ', 'sensitizes_Cultural_Differences',
       ' Condemns_Discrimination_Cultural',
       ' Different_Cultural_Do_ Not_ Face_Problem ',
       ' Conducts_Sensitivity_Training', ' Organisation_Celebrates_Festivals ',
       'Canteen_Serves_Cuisines', 'Cultural_Background_Colleagues ',
       'Religious_Customs', 'Working _Homogeneous_Teams ']

# %%
df_t = df[init]
df_p = df[init_p]
df_s = df[init_s]

# %%
#histogram
sns.distplot(df['Appreciating_Cultural_Differences  ']);

# %%
#histogram
sns.distplot(df['Cross-Cultural_Management ']);

# %%
#histogram
sns.distplot(df[' Imparts_Training ']);

# %%
#histogram
sns.distplot(df['sensitizes_Cultural_Differences']);

# %%
#histogram
sns.distplot(df[' Condemns_Discrimination_Cultural']);

# %%
#histogram
sns.distplot(df[' Different_Cultural_Do_ Not_ Face_Problem ']);

# %%
#histogram
sns.distplot(df[' Different_Cultural_Do_ Not_ Face_Problem ']);

# %%
#histogram
sns.distplot(df[' Conducts_Sensitivity_Training']);

# %%
#histogram
sns.distplot(df[' Organisation_Celebrates_Festivals ']);

# %%
#histogram
sns.distplot(df['Canteen_Serves_Cuisines']);

# %%
#histogram
sns.distplot(df['Cultural_Background_Colleagues ']);

# %%
#histogram
sns.distplot(df['Religious_Customs']);

# %%
#histogram
sns.distplot(df['Working _Homogeneous_Teams ']);

# %%
#histogram
sns.distplot(df['Gender_Inclusivity ']);

# %%
#histogram
sns.distplot(df['Contextual_Differences']);

# %%
#histogram
sns.distplot(df['Treats_men&women_equally']);

# %%
#histogram
sns.distplot(df['Recruitment_Gender_Parity']);

# %%
#histogram
sns.distplot(df['Supports_Women_Aspire ']);

# %%
#histogram
sns.distplot(df['Women_Effective_Men_Leadership']);

# %%
#histogram
sns.distplot(df['Policies_Women_Employees ']);

# %%
#histogram
sns.distplot(df['Women_Safety ']);

# %%
#histogram
sns.distplot(df[' Prevent_Sexual_Harassment']);

# %%
#histogram
sns.distplot(df[' Zero_Tolerance_Sexual_Harassment']);

# %%
from sklearn import preprocessing 
le = preprocessing.LabelEncoder()

# %%
for col in df_1.columns:
        for col in df_1.columns:
            if col in ['Organisation', 'Department', 'Gender', 'Age']:
                df_1[col]= le.fit_transform(df_1[col])

# %%
for col in df_2.columns:
        for col in df_2.columns:
            if col in ['Organisation', 'Department', 'Gender', 'Age']:
                df_2[col]= le.fit_transform(df_2[col])

# %%
df_1 = pd.concat([df_t,df_p],axis =1)

# %%
df_2 = pd.concat([df_t,df_s],axis=1)

# %%
t= df_1.corr()
pd.DataFrame(t)
# Out:
#                                    Organisation  Department    Gender  \
# Organisation                           1.000000    0.257817 -0.109763
# Department                             0.257817    1.000000 -0.160449
# Gender                                -0.109763   -0.160449  1.000000
# Age                                    0.477164   -0.011926  0.110119
# Gender_Inclusivity                     0.259675    0.259837 -0.109422
# Contextual_Differences                -0.092296   -0.083895 -0.071563
# Treats_men&women_equally               0.026175    0.182605 -0.067966
# Recruitment_Gender_Parity              0.013379    0.252229 -0.035776
# Supports_Women_Aspire                 -0.049045    0.056270 -0.047710
# Women_Effective_Men_Leadership        -0.203982    0.100592 -0.103097
# Facilities_Women_Employees            -0.195663    0.004918 -0.114594
# Policies_Women_Employees              -0.040456    0.039181 -0.161119
# ...

# %%
s= df_2.corr()
pd.DataFrame(s)
# Out:
#                                             Organisation  Department  \
# Organisation                                    1.000000    0.257817
# Department                                      0.257817    1.000000
# Gender                                         -0.109763   -0.160449
# Age                                             0.477164   -0.011926
# Appreciating_Cultural_Differences               0.336995    0.317961
# Cross-Cultural_Management                       0.087341    0.147676
#  Imparts_Training                              -0.176869    0.118001
# sensitizes_Cultural_Differences                -0.321231   -0.207537
#  Condemns_Discrimination_Cultural              -0.152022    0.123531
#  Different_Cultural_Do_ Not_ Face_Problem      -0.108324   -0.111957
#  Conducts_Sensitivity_Training                 -0.484018    0.004678
#  Organisation_Celebrates_Festivals             -0.276702   -0.278880
# Canteen_Serves_Cuisines                        -0.601440   -0.358809
# ...

# %%
#correlation matrix
corrmat = df_1.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#correlation matrix
corrmat = df_2.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
df_1.groupby(['Organisation']).mean()
# Out:
#               Gender_Inclusivity   Contextual_Differences  \
# Organisation
# BSS                      4.121951                3.987805
# UNDP                     4.500000                3.850000
#
#               Treats_men&women_equally  Recruitment_Gender_Parity  \
# Organisation
# BSS                           4.219512                    4.02439
# UNDP                          4.250000                    4.05000
#
#               Supports_Women_Aspire   Women_Effective_Men_Leadership  \
# Organisation
# BSS                          4.02439                        4.585366
# UNDP                         3.95000                        4.250000
#
#               Facilities_Women_Employees  Policies_Women_Employees   \
# Organisation
# BSS                             3.902439                   4.012195
# UNDP                            3.550000                   3.950000
#
#               Women_Safety    Prevent_Sexual_Harassment  \
# Organisation
# ...

# %%
df_2.groupby(['Organisation']).mean()
# Out:
#               Appreciating_Cultural_Differences    Cross-Cultural_Management   \
# Organisation
# BSS                                      3.707317                     4.52439
# UNDP                                     4.650000                     4.65000
#
#                Imparts_Training   sensitizes_Cultural_Differences  \
# Organisation
# BSS                     3.292683                         3.304878
# UNDP                    2.900000                         2.650000
#
#                Condemns_Discrimination_Cultural  \
# Organisation
# BSS                                     4.54878
# UNDP                                    4.35000
#
#                Different_Cultural_Do_ Not_ Face_Problem   \
# Organisation
# BSS                                             3.792683
# UNDP                                            3.600000
#
#                Conducts_Sensitivity_Training  \
# Organisation
# BSS                                 3.353659
# ...

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df_1.groupby(['Organisation']).hist(bins=bin_values, figsize=[14,6])
# Out:
# Organisation
# BSS     [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# UNDP    [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# dtype: object

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df_2.groupby(['Organisation']).hist(bins=bin_values, figsize=[14,6])
# Out:
# Organisation
# BSS     [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# UNDP    [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# dtype: object

# %%
df_1.groupby(['Department']).mean()
# Out:
#                            Gender_Inclusivity   Contextual_Differences  \
# Department
# BCUK - Fraud Chargeback               3.909091                3.909091
# BCUK - Fraud Chargeback               3.000000                4.000000
# Chargeback                            4.000000                4.000000
# Chargebacks                           4.000000                4.000000
# Credit Chargeback                     4.000000                3.000000
# Customer care                         4.000000                4.000000
# Debit Fraud Chargeback                4.100000                4.300000
# Democratic Governance                 4.000000                4.000000
# Falcon                                4.090909                3.909091
# Governance                            4.250000                4.000000
# Governance                            5.000000                4.000000
# Indemnities                           4.200000                4.200000
# ...

# %%
df_2.groupby(['Department']).mean()
# Out:
#                            Appreciating_Cultural_Differences    \
# Department
# BCUK - Fraud Chargeback                               3.636364
# BCUK - Fraud Chargeback                               5.000000
# Chargeback                                            1.000000
# Chargebacks                                           1.000000
# Credit Chargeback                                     4.000000
# Customer care                                         1.000000
# Debit Fraud Chargeback                                3.500000
# Democratic Governance                                 5.000000
# Falcon                                                3.454545
# Governance                                            4.500000
# Governance                                            5.000000
# Indemnities                                           3.900000
# NON FRAUD CHARGEBACKS                                 3.000000
# Non Fraud Chargeback                                  4.142857
# ...

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df_2.groupby(['Department']).hist(bins=bin_values, figsize=[14,10])
# Out:
# Department
# BCUK - Fraud Chargeback      [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# BCUK - Fraud Chargeback      [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Chargeback                   [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Chargebacks                  [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Credit Chargeback            [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Customer care                [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Debit Fraud Chargeback       [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Democratic Governance        [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Falcon                       [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Governance                   [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Governance                   [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Indemnities                  [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# ...

# %%
df_1.groupby(['Gender']).mean()
# Out:
#         Gender_Inclusivity   Contextual_Differences  Treats_men&women_equally  \
# Gender
# Female             4.254545                4.000000                  4.254545
# Male               4.127660                3.914894                  4.191489
#
#         Recruitment_Gender_Parity  Supports_Women_Aspire   \
# Gender
# Female                   4.054545                4.036364
# Male                     4.000000                3.978723
#
#         Women_Effective_Men_Leadership  Facilities_Women_Employees  \
# Gender
# Female                        4.581818                    3.909091
# Male                          4.446809                    3.744681
#
#         Policies_Women_Employees   Women_Safety    Prevent_Sexual_Harassment  \
# Gender
# Female                   4.090909       4.363636                    4.381818
# Male                     3.893617       4.234043                    4.404255
#
#          Zero_Tolerance_Sexual_Harassment
# Gender
# ...

# %%
df_2.groupby(['Gender']).mean()
# Out:
#         Appreciating_Cultural_Differences    Cross-Cultural_Management   \
# Gender
# Female                             4.000000                    4.672727
# Male                               3.765957                    4.404255
#
#          Imparts_Training   sensitizes_Cultural_Differences  \
# Gender
# Female            3.290909                         3.163636
# Male              3.127660                         3.191489
#
#          Condemns_Discrimination_Cultural  \
# Gender
# Female                           4.454545
# Male                             4.574468
#
#          Different_Cultural_Do_ Not_ Face_Problem   \
# Gender
# Female                                    3.854545
# Male                                      3.638298
#
#          Conducts_Sensitivity_Training   Organisation_Celebrates_Festivals   \
# Gender
# Female                        3.181818                             3.472727
# ...

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df_1.groupby(['Gender']).hist(bins=bin_values, figsize=[14,6])
# Out:
# Gender
# Female    [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Male      [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# dtype: object

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df_2.groupby(['Gender']).hist(bins=bin_values, figsize=[14,6])
# Out:
# Gender
# Female    [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Male      [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# dtype: object

# %%
df_1.groupby(['Age']).mean()
# Out:
#           Gender_Inclusivity   Contextual_Differences  \
# Age
# 20-30                4.157895                3.947368
# 30-40                4.155556                4.000000
# 40-50                4.222222                3.666667
# Above 50             4.500000                4.100000
#
#           Treats_men&women_equally  Recruitment_Gender_Parity  \
# Age
# 20-30                     4.210526                   4.105263
# 30-40                     4.200000                   4.022222
# 40-50                     4.333333                   3.777778
# Above 50                  4.300000                   4.000000
#
#           Supports_Women_Aspire   Women_Effective_Men_Leadership  \
# Age
# 20-30                   3.973684                        4.631579
# 30-40                   4.066667                        4.488889
# 40-50                   3.888889                        4.333333
# Above 50                4.000000                        4.400000
#
# ...

# %%
df_2.groupby(['Age']).mean()
# Out:
#           Appreciating_Cultural_Differences    Cross-Cultural_Management   \
# Age
# 20-30                                4.000000                    4.631579
# 30-40                                3.622222                    4.488889
# 40-50                                4.222222                    4.555556
# Above 50                             4.400000                    4.500000
#
#            Imparts_Training   sensitizes_Cultural_Differences  \
# Age
# 20-30               3.500000                         3.368421
# 30-40               3.088889                         3.133333
# 40-50               2.777778                         3.000000
# Above 50            3.100000                         2.800000
#
#            Condemns_Discrimination_Cultural  \
# Age
# 20-30                              4.605263
# 30-40                              4.488889
# 40-50                              4.444444
# Above 50                           4.300000
#
# ...

# %%
bin_values = np.arange(start=0, stop=5, step=1)
df_1.groupby(['Age']).hist(bins=bin_values, figsize=[14,6])
# Out:
# Age
# 20-30       [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# 30-40       [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# 40-50       [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Above 50    [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# dtype: object

# %%
bin_values = np.arange(start=0, stop=3, step=1)
df_2.groupby(['Age']).hist(bins=bin_values, figsize=[14,10])
# Out:
# Age
# 20-30       [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# 30-40       [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# 40-50       [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# Above 50    [[Axes(0.125,0.725918;0.215278x0.154082), Axes...
# dtype: object

# %% [markdown]
# # Pricipal Component Analysis

# %%
import pandas as pd
import pylab as pl
from sklearn import datasets
from sklearn.decomposition import PCA

# %%
# normalize data
from sklearn import preprocessing
data_scaled = pd.DataFrame(preprocessing.scale(df),columns = df.columns)

# %%
# PCA
pca = PCA(n_components=2)
pca.fit_transform(data_scaled)
# Out:
# array([[-0.05512708,  2.87656559],
#        [-2.9954442 ,  4.5792043 ],
#        [ 2.42355656,  2.07122007],
#        [ 1.03933581,  0.04174525],
#        [ 0.43124801,  2.30846051],
#        [ 0.88195839, -0.65034062],
#        [ 3.9016686 , -0.87736324],
#        [-5.26846471, -2.48333727],
#        [ 4.1686474 ,  0.58214316],
#        [ 4.88119538,  1.60031751],
#        [ 4.45118793,  2.22896556],
#        [ 3.37924658,  3.39827893],
#        [ 2.83906807,  2.68375621],
#        [-0.63997894,  5.40431955],
#        [ 1.62535028,  2.46865457],
#        [ 1.8128253 ,  1.23602068],
#        [ 2.89274901, -0.09923769],
#        [ 1.6476867 ,  1.04302587],
#        [ 1.82596399,  1.52515231],
#        [ 3.01968381, -0.57345041],
#        [ 7.60598918,  1.65112936],
#        [ 3.89084064,  1.42733755],
#        [ 1.91851958,  4.69255947],
#        [-0.72120138, -2.97451037],
#        [-1.88321934, -3.3778626 ],
#        [-3.40171439, -3.65405688],
#        [-0.23474766, -1.17601861],
# ...

# %%
# Dump components relations with features:
print(pd.DataFrame(pca.components_,columns=data_scaled.columns,index = ['PC-1','PC-2']))
# Out:
#       Organisation  Department    Gender       Age  \
# PC-1      0.196686    0.006097  0.047420  0.123108
# PC-2      0.283576    0.281033 -0.053012  0.173537
#
#       Appreciating_Cultural_Differences    Cross-Cultural_Management   \
# PC-1                             0.019098                    0.015196
# PC-2                             0.178921                    0.128971
#
#        Imparts_Training   sensitizes_Cultural_Differences  \
# PC-1           -0.183602                        -0.234655
# PC-2           -0.172123                        -0.240959
#
#        Condemns_Discrimination_Cultural  \
# PC-1                          -0.108673
# PC-2                           0.079267
#
#        Different_Cultural_Do_ Not_ Face_Problem   \
# PC-1                                   -0.091693
# PC-2                                   -0.157004
#
#                     ...                  Contextual_Differences  \
# PC-1                ...                               -0.243964
# ...

# %%
#Description of PCA/Factor Analysis
#https://plot.ly/ipython-notebooks/principal-component-analysis/
#http://blog.districtdatalabs.com/principal-component-analysis-with-python
#https://jakevdp.github.io/PythonDataScienceHandbook/05.09-principal-component-analysis.html

# %% [markdown]
# # Anova

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#cw_lm=ols('weight ~ Time + C(Diet)', data=cw).fit() #Specify C for Categorical

# %%
#print(sm.stats.anova_lm(cw_lm, typ=2))
